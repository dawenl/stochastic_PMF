# %%
import functools
import os
import numpy as np

import pnmf

# %%
specshow = functools.partial(imshow, cmap=cm.PuOr_r, aspect='auto', interpolation='nearest')

# %%
train_tracks = list()
with open('train_tracks.txt', 'rb') as f:
    for line in f:
        train_tracks.append(line.strip())
        
test_tracks = list()
with open('test_tracks.txt', 'rb') as f:
    for line in f:
        test_tracks.append(line.strip())
        
tags = list()
with open('voc.txt', 'rb') as f:
    for line in f:
        tags.append(line.strip())

# %% [markdown]
# # Batch inference on 10K subset

# %%
K = 1024

np.random.seed(98765)
train_tracks_subset = np.random.choice(train_tracks, size=10000, replace=False)

# %%
D = K + len(tags)

X = np.empty((10000, D), dtype=np.int16)

for (i, tid) in enumerate(train_tracks_subset):
    tdir = os.path.join('vq_hist', '/'.join(tid[2:5]))
    vq = np.load(os.path.join(tdir, '%s_K%d.npy' % (tid, K))).ravel()
    bot = np.load(os.path.join(tdir, '%s_BoT.npy' % tid))
    X[i] = np.hstack((vq, bot))

# %%
specshow(X[:, :K])
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x2e68a2d8>

# %%
# take tracks with at least 20 tags from test set
X_test = None

for tid in test_tracks:
    tdir = os.path.join('vq_hist', '/'.join(tid[2:5]))
    bot = np.load(os.path.join(tdir, '%s_BoT.npy' % tid))
    if (bot > 0).sum() >= 20:
        vq = np.load(os.path.join(tdir, '%s_K%d.npy' % (tid, K))).ravel()
        if X_test is None:
            X_test = np.hstack((vq, bot))
        else:
            X_test = np.vstack((X_test, np.hstack((vq, bot))))
pass

# %%
hist(np.sum( (X_test[:, K:] > 0), axis=1), bins=50)
pass

# %%
n_components = 128
coder = pnmf.PoissonNMF(n_components=n_components, random_state=98765, verbose=True)

# %%
coder.fit(X)
# Out:
# After ITERATION: 0	Objective: -11015473.88	Old objective: -inf	Improvement: nan
# After ITERATION: 1	Objective: -10467052.85	Old objective: -11015473.88	Improvement: 0.04979
# After ITERATION: 2	Objective: -10435081.34	Old objective: -10467052.85	Improvement: 0.00305
# After ITERATION: 3	Objective: -10354877.79	Old objective: -10435081.34	Improvement: 0.00769
# After ITERATION: 4	Objective: -10124543.00	Old objective: -10354877.79	Improvement: 0.02224
# After ITERATION: 5	Objective: -9417216.23	Old objective: -10124543.00	Improvement: 0.06986
# After ITERATION: 6	Objective: -7519749.22	Old objective: -9417216.23	Improvement: 0.20149
# After ITERATION: 7	Objective: -4287162.63	Old objective: -7519749.22	Improvement: 0.42988
# After ITERATION: 8	Objective: -970228.90	Old objective: -4287162.63	Improvement: 0.77369
# After ITERATION: 9	Objective: 1665730.24	Old objective: -970228.90	Improvement: 2.71684
# After ITERATION: 10	Objective: 3589582.49	Old objective: 1665730.24	Improvement: 1.15496
# After ITERATION: 11	Objective: 4974482.99	Old objective: 3589582.49	Improvement: 0.38581
# After ITERATION: 12	Objective: 5983220.96	Old objective: 4974482.99	Improvement: 0.20278
# After ITERATION: 13	Objective: 6719064.88	Old objective: 5983220.96	Improvement: 0.12298
# After ITERATION: 14	Objective: 7255614.17	Old objective: 6719064.88	Improvement: 0.07985
# After ITERATION: 15	Objective: 7650606.96	Old objective: 7255614.17	Improvement: 0.05444
# After ITERATION: 16	Objective: 7942838.58	Old objective: 7650606.96	Improvement: 0.03820
# After ITERATION: 17	Objective: 8161295.72	Old objective: 7942838.58	Improvement: 0.02750
# After ITERATION: 18	Objective: 8327966.19	Old objective: 8161295.72	Improvement: 0.02042
# After ITERATION: 19	Objective: 8457618.92	Old objective: 8327966.19	Improvement: 0.01557
# After ITERATION: 20	Objective: 8560592.84	Old objective: 8457618.92	Improvement: 0.01218
# After ITERATION: 21	Objective: 8643927.50	Old objective: 8560592.84	Improvement: 0.00973
# After ITERATION: 22	Objective: 8712314.77	Old objective: 8643927.50	Improvement: 0.00791
# After ITERATION: 23	Objective: 8768237.20	Old objective: 8712314.77	Improvement: 0.00642
# After ITERATION: 24	Objective: 8814070.28	Old objective: 8768237.20	Improvement: 0.00523
# After ITERATION: 25	Objective: 8852181.43	Old objective: 8814070.28	Improvement: 0.00432
# After ITERATION: 26	Objective: 8884288.17	Old objective: 8852181.43	Improvement: 0.00363
# After ITERATION: 27	Objective: 8911676.24	Old objective: 8884288.17	Improvement: 0.00308
# After ITERATION: 28	Objective: 8935323.42	Old objective: 8911676.24	Improvement: 0.00265
# After ITERATION: 29	Objective: 8956048.99	Old objective: 8935323.42	Improvement: 0.00232
# After ITERATION: 30	Objective: 8974019.08	Old objective: 8956048.99	Improvement: 0.00201
# After ITERATION: 31	Objective: 8989777.70	Old objective: 8974019.08	Improvement: 0.00176
# After ITERATION: 32	Objective: 9003621.98	Old objective: 8989777.70	Improvement: 0.00154
# After ITERATION: 33	Objective: 9015787.73	Old objective: 9003621.98	Improvement: 0.00135
# After ITERATION: 34	Objective: 9026751.95	Old objective: 9015787.73	Improvement: 0.00122
# After ITERATION: 35	Objective: 9036816.30	Old objective: 9026751.95	Improvement: 0.00111
# After ITERATION: 36	Objective: 9046050.33	Old objective: 9036816.30	Improvement: 0.00102
# After ITERATION: 37	Objective: 9054491.65	Old objective: 9046050.33	Improvement: 0.00093
# After ITERATION: 38	Objective: 9062127.72	Old objective: 9054491.65	Improvement: 0.00084
# After ITERATION: 39	Objective: 9069032.81	Old objective: 9062127.72	Improvement: 0.00076
# After ITERATION: 40	Objective: 9075337.63	Old objective: 9069032.81	Improvement: 0.00070
# After ITERATION: 41	Objective: 9081148.96	Old objective: 9075337.63	Improvement: 0.00064
# After ITERATION: 42	Objective: 9086460.05	Old objective: 9081148.96	Improvement: 0.00058
# After ITERATION: 43	Objective: 9091351.22	Old objective: 9086460.05	Improvement: 0.00054
# After ITERATION: 44	Objective: 9095906.09	Old objective: 9091351.22	Improvement: 0.00050
# After ITERATION: 45	Objective: 9100065.02	Old objective: 9095906.09	Improvement: 0.00046
# PoissonNMF(max_iter=100, n_components=128, random_state=98765, smoothness=100,
#       tol=0.0005, verbose=True)

# %%
# plot 10 "topics"
indices = np.random.choice(n_components, size=10, replace=False)
figure(figsize=(16, 15))
for i in xrange(10):
    subplot(5, 2, i+1)
    bar(np.arange(D), coder.Eb[indices[i]])
    title('Component #%d' % indices[i])

# %%
tagger = pnmf.PoissonNMF(n_components=n_components, random_state=98765, verbose=True)

# %%
tagger.set_components(coder.gamma_b[:, :K], coder.rho_b)

# %%
Et = tagger.transform(X_test[:, :K])
# Out:
# After ITERATION: 0	Objective: 414282.81	Old objective: -inf	Improvement: nan
# After ITERATION: 1	Objective: 1137148.35	Old objective: 414282.81	Improvement: 1.74486
# After ITERATION: 2	Objective: 1356834.01	Old objective: 1137148.35	Improvement: 0.19319
# After ITERATION: 3	Objective: 1459163.59	Old objective: 1356834.01	Improvement: 0.07542
# After ITERATION: 4	Objective: 1514867.15	Old objective: 1459163.59	Improvement: 0.03817
# After ITERATION: 5	Objective: 1548721.62	Old objective: 1514867.15	Improvement: 0.02235
# After ITERATION: 6	Objective: 1571068.01	Old objective: 1548721.62	Improvement: 0.01443
# After ITERATION: 7	Objective: 1586732.08	Old objective: 1571068.01	Improvement: 0.00997
# After ITERATION: 8	Objective: 1598146.44	Old objective: 1586732.08	Improvement: 0.00719
# After ITERATION: 9	Objective: 1606793.13	Old objective: 1598146.44	Improvement: 0.00541
# After ITERATION: 10	Objective: 1613547.77	Old objective: 1606793.13	Improvement: 0.00420
# After ITERATION: 11	Objective: 1618932.74	Old objective: 1613547.77	Improvement: 0.00334
# After ITERATION: 12	Objective: 1623301.84	Old objective: 1618932.74	Improvement: 0.00270
# After ITERATION: 13	Objective: 1626905.66	Old objective: 1623301.84	Improvement: 0.00222
# After ITERATION: 14	Objective: 1629919.20	Old objective: 1626905.66	Improvement: 0.00185
# After ITERATION: 15	Objective: 1632464.37	Old objective: 1629919.20	Improvement: 0.00156
# After ITERATION: 16	Objective: 1634639.18	Old objective: 1632464.37	Improvement: 0.00133
# After ITERATION: 17	Objective: 1636506.27	Old objective: 1634639.18	Improvement: 0.00114
# After ITERATION: 18	Objective: 1638123.73	Old objective: 1636506.27	Improvement: 0.00099
# After ITERATION: 19	Objective: 1639552.38	Old objective: 1638123.73	Improvement: 0.00087
# After ITERATION: 20	Objective: 1640819.39	Old objective: 1639552.38	Improvement: 0.00077
# After ITERATION: 21	Objective: 1641953.51	Old objective: 1640819.39	Improvement: 0.00069
# After ITERATION: 22	Objective: 1642965.21	Old objective: 1641953.51	Improvement: 0.00062
# After ITERATION: 23	Objective: 1643867.22	Old objective: 1642965.21	Improvement: 0.00055
# After ITERATION: 24	Objective: 1644680.53	Old objective: 1643867.22	Improvement: 0.00049

# %%
tags_predicted = Et.dot(coder.Eb[:, K:])

# %%
tags_predicted.max()
# Out:
# 1451.1043144215057

# %%
figure(figsize=(16, 8))
tmp = tags_predicted.copy()
subplot(211)
specshow((tmp >= 1), cmap=cm.gray)
colorbar()
subplot(212)
specshow((X_test[:, K:] > 0), cmap=cm.gray)
colorbar()
pass

# %% [markdown]
# # Stochastic inference on 10K subset

# %%
online_coder = pnmf.OnlinePoissonNMF()

# %% [markdown]
# # Stochastic inference on the full set

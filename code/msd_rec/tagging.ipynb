# %%
import functools
import os
import numpy as np
from joblib import Parallel, delayed

import pnmf

# %%
specshow = functools.partial(imshow, cmap=cm.PuOr_r, aspect='auto', interpolation='nearest')

# %%
train_tracks = list()
with open('train_tracks.txt', 'rb') as f:
    for line in f:
        train_tracks.append(line.strip())
        
test_tracks = list()
with open('test_tracks.txt', 'rb') as f:
    for line in f:
        test_tracks.append(line.strip())
        
tags = list()
with open('voc.txt', 'rb') as f:
    for line in f:
        tags.append(line.strip())

# %%
def construct_pred_mask(tags_predicted, predictat):
    n_samples, n_tags = tags_predicted.shape
    rankings = np.argsort(-tags_predicted, axis=1)[:, :predictat]
    tags_predicted_binary = np.zeros_like(tags_predicted, dtype=bool)
    for i in xrange(n_samples):
        tags_predicted_binary[i, rankings[i]] = 1
    return tags_predicted_binary

def per_tag_prec_recall(tags_predicted_binary, tags_true_binary):
    mask = np.logical_and(tags_predicted_binary, tags_true_binary)
    prec = mask.sum(axis=0) / (np.sum(tags_predicted_binary, axis=0) + np.spacing(1))
    recall = mask.sum(axis=0) / (np.sum(tags_true_binary, axis=0) + np.spacing(1))
    return prec, recall

# %%
# take tracks with at least 20 tags 
y_test = None

test_tracks_selected = list()

for tid in test_tracks:
    tdir = os.path.join('vq_hist', '/'.join(tid[2:5]))
    bot = np.load(os.path.join(tdir, '%s_BoT.npy' % tid))
    if (bot > 0).sum() >= 20:
        test_tracks_selected.append(tid)
        if y_test is None:
            y_test = bot
        else:
            y_test = np.vstack((y_test, bot))

# %%
hist(np.sum( (y_test > 0), axis=1), bins=50)
pass

# %% [markdown]
# # Batch inference on 10K subset

# %%
K = 512

np.random.seed(98765)
train_tracks_subset = np.random.choice(train_tracks, size=10000, replace=False)

# %%
D = K + len(tags)

X = np.empty((10000, D), dtype=np.int16)

for (i, tid) in enumerate(train_tracks_subset):
    tdir = os.path.join('vq_hist', '/'.join(tid[2:5]))
    vq = np.load(os.path.join(tdir, '%s_K%d.npy' % (tid, K))).ravel()
    bot = np.load(os.path.join(tdir, '%s_BoT.npy' % tid))
    bot[bot > 0] = 1
    X[i] = np.hstack((vq, bot))

# %%
bar(np.arange(D), X[1000])
# Out:
# <Container object of 1073 artists>

# %%
X_test = np.empty((len(test_tracks_selected), K), dtype=int16)

for (i, tid) in enumerate(test_tracks_selected):
    tdir = os.path.join('vq_hist', '/'.join(tid[2:5]))
    vq = np.load(os.path.join(tdir, '%s_K%d.npy' % (tid, K))).ravel()
    X_test[i] = vq

# %%
reload(pnmf)
n_components = 100
coder = pnmf.PoissonNMF(n_components=n_components, random_state=98765, verbose=True)

# %%
coder.fit(X)
# Out:
# After ITERATION: 0	Objective: -2078575.38	Old objective: -inf	Improvement: nan
# After ITERATION: 1	Objective: -2065917.26	Old objective: -2078575.38	Improvement: 0.00609
# After ITERATION: 2	Objective: -2033967.12	Old objective: -2065917.26	Improvement: 0.01547
# After ITERATION: 3	Objective: -1936479.76	Old objective: -2033967.12	Improvement: 0.04793
# After ITERATION: 4	Objective: -1606168.41	Old objective: -1936479.76	Improvement: 0.17057
# After ITERATION: 5	Objective: -625410.26	Old objective: -1606168.41	Improvement: 0.61062
# After ITERATION: 6	Objective: 1186505.37	Old objective: -625410.26	Improvement: 2.89716
# After ITERATION: 7	Objective: 3236615.52	Old objective: 1186505.37	Improvement: 1.72786
# After ITERATION: 8	Objective: 4934011.49	Old objective: 3236615.52	Improvement: 0.52444
# After ITERATION: 9	Objective: 6219149.21	Old objective: 4934011.49	Improvement: 0.26047
# After ITERATION: 10	Objective: 7228762.41	Old objective: 6219149.21	Improvement: 0.16234
# After ITERATION: 11	Objective: 8020978.80	Old objective: 7228762.41	Improvement: 0.10959
# After ITERATION: 12	Objective: 8613082.17	Old objective: 8020978.80	Improvement: 0.07382
# After ITERATION: 13	Objective: 9042163.99	Old objective: 8613082.17	Improvement: 0.04982
# After ITERATION: 14	Objective: 9354931.77	Old objective: 9042163.99	Improvement: 0.03459
# After ITERATION: 15	Objective: 9588474.79	Old objective: 9354931.77	Improvement: 0.02496
# After ITERATION: 16	Objective: 9766886.10	Old objective: 9588474.79	Improvement: 0.01861
# After ITERATION: 17	Objective: 9905911.01	Old objective: 9766886.10	Improvement: 0.01423
# After ITERATION: 18	Objective: 10015808.46	Old objective: 9905911.01	Improvement: 0.01109
# After ITERATION: 19	Objective: 10103284.44	Old objective: 10015808.46	Improvement: 0.00873
# After ITERATION: 20	Objective: 10173460.99	Old objective: 10103284.44	Improvement: 0.00695
# After ITERATION: 21	Objective: 10230221.19	Old objective: 10173460.99	Improvement: 0.00558
# After ITERATION: 22	Objective: 10276701.49	Old objective: 10230221.19	Improvement: 0.00454
# After ITERATION: 23	Objective: 10315331.10	Old objective: 10276701.49	Improvement: 0.00376
# After ITERATION: 24	Objective: 10347758.51	Old objective: 10315331.10	Improvement: 0.00314
# After ITERATION: 25	Objective: 10375178.66	Old objective: 10347758.51	Improvement: 0.00265
# After ITERATION: 26	Objective: 10398602.02	Old objective: 10375178.66	Improvement: 0.00226
# After ITERATION: 27	Objective: 10418784.49	Old objective: 10398602.02	Improvement: 0.00194
# After ITERATION: 28	Objective: 10436324.37	Old objective: 10418784.49	Improvement: 0.00168
# After ITERATION: 29	Objective: 10451653.91	Old objective: 10436324.37	Improvement: 0.00147
# After ITERATION: 30	Objective: 10465160.29	Old objective: 10451653.91	Improvement: 0.00129
# After ITERATION: 31	Objective: 10477122.63	Old objective: 10465160.29	Improvement: 0.00114
# After ITERATION: 32	Objective: 10487779.16	Old objective: 10477122.63	Improvement: 0.00102
# After ITERATION: 33	Objective: 10497320.68	Old objective: 10487779.16	Improvement: 0.00091
# After ITERATION: 34	Objective: 10505902.89	Old objective: 10497320.68	Improvement: 0.00082
# After ITERATION: 35	Objective: 10513654.10	Old objective: 10505902.89	Improvement: 0.00074
# After ITERATION: 36	Objective: 10520677.05	Old objective: 10513654.10	Improvement: 0.00067
# After ITERATION: 37	Objective: 10527099.69	Old objective: 10520677.05	Improvement: 0.00061
# After ITERATION: 38	Objective: 10532939.39	Old objective: 10527099.69	Improvement: 0.00055
# After ITERATION: 39	Objective: 10538249.22	Old objective: 10532939.39	Improvement: 0.00050
# After ITERATION: 40	Objective: 10543112.34	Old objective: 10538249.22	Improvement: 0.00046
# PoissonNMF(max_iter=100, n_components=100, random_state=98765, smoothness=100,
#       tol=0.0005, verbose=True)

# %%
# randomly plot 30 "topics"
indices = np.random.choice(n_components, size=30, replace=False)
figure(figsize=(45, 15))
for i in xrange(30):
    subplot(10, 3, i+1)
    topic = coder.Eb[indices[i]].copy()
    # properly normalize the BoT dimensions for visualization purposes
    topic[K:] /= topic[K:].max()
    topic[K:] *= topic[:K].max()
    bar(np.arange(D), topic)
    axvline(x=K, color='red')
    title('Component #%d' % indices[i])
#savefig('dict.eps')

# %%
tagger = pnmf.PoissonNMF(n_components=n_components, random_state=98765, verbose=True)

# %%
tagger.set_components(coder.gamma_b[:, :K], coder.rho_b)

# %%
Et = tagger.transform(X_test)
# Out:
# After ITERATION: 0	Objective: 2368001.32	Old objective: -inf	Improvement: nan
# After ITERATION: 1	Objective: 2884730.63	Old objective: 2368001.32	Improvement: 0.21821
# After ITERATION: 2	Objective: 3066546.42	Old objective: 2884730.63	Improvement: 0.06303
# After ITERATION: 3	Objective: 3152016.68	Old objective: 3066546.42	Improvement: 0.02787
# After ITERATION: 4	Objective: 3199459.34	Old objective: 3152016.68	Improvement: 0.01505
# After ITERATION: 5	Objective: 3228816.24	Old objective: 3199459.34	Improvement: 0.00918
# After ITERATION: 6	Objective: 3248345.84	Old objective: 3228816.24	Improvement: 0.00605
# After ITERATION: 7	Objective: 3262115.95	Old objective: 3248345.84	Improvement: 0.00424
# After ITERATION: 8	Objective: 3272237.54	Old objective: 3262115.95	Improvement: 0.00310
# After ITERATION: 9	Objective: 3279912.21	Old objective: 3272237.54	Improvement: 0.00235
# After ITERATION: 10	Objective: 3285932.19	Old objective: 3279912.21	Improvement: 0.00184
# After ITERATION: 11	Objective: 3290740.81	Old objective: 3285932.19	Improvement: 0.00146
# After ITERATION: 12	Objective: 3294641.25	Old objective: 3290740.81	Improvement: 0.00119
# After ITERATION: 13	Objective: 3297852.60	Old objective: 3294641.25	Improvement: 0.00097
# After ITERATION: 14	Objective: 3300551.52	Old objective: 3297852.60	Improvement: 0.00082
# After ITERATION: 15	Objective: 3302852.84	Old objective: 3300551.52	Improvement: 0.00070
# After ITERATION: 16	Objective: 3304829.50	Old objective: 3302852.84	Improvement: 0.00060
# After ITERATION: 17	Objective: 3306509.84	Old objective: 3304829.50	Improvement: 0.00051
# After ITERATION: 18	Objective: 3307951.64	Old objective: 3306509.84	Improvement: 0.00044

# %%
tags_predicted = Et.dot(coder.Eb[:, K:])
n_samples, n_tags = tags_predicted.shape

print tags_predicted.min(), tags_predicted.max()

div_factor = 5
tags_predicted = tags_predicted - div_factor * np.mean(tags_predicted, axis=0)
# Out:
# 0.000717104868385 223.30715545

# %%
predictat = 20
tags_predicted_binary = construct_pred_mask(tags_predicted, predictat)
tags_true_binary = (y_test > 0)

# %%
prec, recall = per_tag_prec_recall(tags_predicted_binary, tags_true_binary)
print np.mean(prec), np.std(prec) / sqrt(n_tags)
print np.mean(recall), np.std(recall) / sqrt(n_tags)
# Out:
# 0.111539065677 0.00640269203855
# 0.112244155786 0.00590470392936

# %%
tags_random_binary = np.zeros((n_samples, n_tags), dtype=bool)
for i in xrange(n_samples):
    idx = np.random.choice(n_tags, size=predictat, replace=False)
    tags_random_binary[i, idx] = 1

# %%
prec, recall = per_tag_prec_recall(tags_random_binary, tags_true_binary)
print np.mean(prec), np.std(prec) / sqrt(n_tags)
print np.mean(recall), np.std(recall) / sqrt(n_tags)
# Out:
# 0.045723906057 0.00315084732186
# 0.0364782778227 0.00143501465992

# %% [markdown]
# # Stochastic inference on 10K subset

# %%
reload(pnmf)

n_components = 100
online_coder = pnmf.OnlinePoissonNMF(n_components=n_components, batch_size=500, n_pass=10, 
                                     random_state=98765, verbose=True)

# %%
online_coder.fit(X)
# Out:
# Iteration 0: passing through the data...
# Iteration 1: passing through the data...
# Iteration 2: passing through the data...
# Iteration 3: passing through the data...
# Iteration 4: passing through the data...
# Iteration 5: passing through the data...
# Iteration 6: passing through the data...
# Iteration 7: passing through the data...
# Iteration 8: passing through the data...
# Iteration 9: passing through the data...
# OnlinePoissonNMF(batch_size=500, max_iter=100, n_components=100, n_pass=10,
#          random_state=98765, shuffle=True, smoothness=100, tol=0.0005,
#          verbose=True)

# %%
plot(online_coder.bound)
axhline(y=coder._bound(X), color='red')
pass

# %%
# randomly plot 30 "topics"
indices = np.random.choice(n_components, size=30, replace=False)
figure(figsize=(45, 15))
for i in xrange(30):
    subplot(10, 3, i+1)
    topic = online_coder.Eb[indices[i]].copy()
    # properly normalize the BoT dimensions for visualization purposes
    #topic[K:] /= topic[K:].max()
    #topic[K:] *= topic[:K].max()
    bar(np.arange(D), topic)
    axvline(x=K, color='red')
    title('Component #%d' % indices[i])
#savefig('stoc_dict.eps')

# %%
ents = np.zeros((n_components, ))

for k in xrange(n_components):
    ents[k] = scipy.stats.entropy(online_coder.Eb[k])

# %%
idx = np.argsort(-ents)

# %%
plot(ents[idx], '-o')
pass

# %%
tagger = pnmf.PoissonNMF(n_components=n_components, random_state=98765, verbose=True)

# %%
tagger.set_components(online_coder.gamma_b[:, :K], online_coder.rho_b[:, :K])

# %%
Et = tagger.transform(X_test)
# Out:
# After ITERATION: 0	Objective: 2559186.35	Old objective: -inf	Improvement: nan
# After ITERATION: 1	Objective: 2975936.22	Old objective: 2559186.35	Improvement: 0.16284
# After ITERATION: 2	Objective: 3100654.67	Old objective: 2975936.22	Improvement: 0.04191
# After ITERATION: 3	Objective: 3150781.71	Old objective: 3100654.67	Improvement: 0.01617
# After ITERATION: 4	Objective: 3175539.66	Old objective: 3150781.71	Improvement: 0.00786
# After ITERATION: 5	Objective: 3189784.99	Old objective: 3175539.66	Improvement: 0.00449
# After ITERATION: 6	Objective: 3198846.22	Old objective: 3189784.99	Improvement: 0.00284
# After ITERATION: 7	Objective: 3205019.80	Old objective: 3198846.22	Improvement: 0.00193
# After ITERATION: 8	Objective: 3209443.62	Old objective: 3205019.80	Improvement: 0.00138
# After ITERATION: 9	Objective: 3212733.85	Old objective: 3209443.62	Improvement: 0.00103
# After ITERATION: 10	Objective: 3215272.82	Old objective: 3212733.85	Improvement: 0.00079
# After ITERATION: 11	Objective: 3217296.19	Old objective: 3215272.82	Improvement: 0.00063
# After ITERATION: 12	Objective: 3218953.33	Old objective: 3217296.19	Improvement: 0.00052
# After ITERATION: 13	Objective: 3220318.40	Old objective: 3218953.33	Improvement: 0.00042

# %%
tags_predicted = Et.dot(online_coder.Eb[:, K:])
n_samples, n_tags = tags_predicted.shape

print tags_predicted.min(), tags_predicted.max()

div_factor = 3
tags_predicted = tags_predicted - div_factor * np.mean(tags_predicted, axis=0)
# Out:
# 0.000492327026748 10.8818358123

# %%
predictat = 20
tags_predicted_binary = construct_pred_mask(tags_predicted, predictat)
tags_true_binary = (y_test > 0)

# %%
prec, recall = per_tag_prec_recall(tags_predicted_binary, tags_true_binary)
print np.mean(prec), np.std(prec) / sqrt(n_tags)
print np.mean(recall), np.std(recall) / sqrt(n_tags)
# Out:
# 0.0830432327004 0.00680060514326
# 0.108129230967 0.00690007364856

# %% [markdown]
# # Stochastic inference on the full set

# %%
def ooc_fit(obj, train_tracks, K, n_feats):
    n_samples = (len(train_tracks) / obj.batch_size) * obj.batch_size
    obj.scale = float(n_samples) / obj.batch_size
    obj._init_components(n_feats)
    obj.bound = list()
    for count in xrange(obj.n_pass):
        print 'Iteration %d: passing through the data...' % count
        indices = np.arange(n_samples)
        if obj.shuffle:
            np.random.shuffle(indices)
        for (i, istart) in enumerate(xrange(0, n_samples,
                                            obj.batch_size), 1):
            iend = min(istart + obj.batch_size, n_samples)
            obj.rho = (i + obj.t0)**(-obj.kappa)
            mini_batch = np.zeros((iend - istart, n_feats))
            for s in xrange(iend - istart):
                tid = train_tracks[indices[istart + s]]
                #print '\tRead in track: %s' % tid
                tdir = os.path.join('vq_hist', '/'.join(tid[2:5]))
                vq = np.load(os.path.join(tdir, '%s_K%d.npy' % (tid, K))).ravel()
                bot = np.load(os.path.join(tdir, '%s_BoT.npy' % tid))
                bot[bot > 0] = 1                
                mini_batch[s] = np.hstack((vq, bot))
            obj.partial_fit(mini_batch)
            obj.bound.append(obj._stoch_bound(mini_batch))
            if not i % 50:
                print '\t%d mini-batches finished.' % i
    return obj

# %%
reload(pnmf)

n_components = 100
online_coder_full = pnmf.OnlinePoissonNMF(n_components=n_components, batch_size=1000, n_pass=1, 
                                          random_state=98765, verbose=True)

# %%
K = 2048
D = K + len(tags)

online_coder_full = ooc_fit(online_coder_full, train_tracks, K, D)

# %%
plot(online_coder_full.bound)
pass

# %%
np.mean(online_coder_full.bound[-100:])
# Out:
# -81607554.577765435

# %%
# randomly plot 30 "topics"
indices = np.random.choice(n_components, size=30, replace=False)
figure(figsize=(45, 15))
for i in xrange(30):
    subplot(10, 3, i+1)
    topic = online_coder_full.Eb[indices[i]].copy()
    # properly normalize the BoT dimensions for visualization purposes
    #topic[K:] /= topic[K:].max()
    #topic[K:] *= topic[:K].max()
    bar(np.arange(D), topic)
    axvline(x=K, color='red')
    title('Component #%d' % indices[i])
#savefig('stoc_dict.eps')

# %%
ents = np.zeros((n_components, ))

for k in xrange(n_components):
    ents[k] = scipy.stats.entropy(online_coder_full.Eb[k])

# %%
idx = np.argsort(-ents)

# %%
plot(ents[idx], '-o')
pass

# %%
tagger = pnmf.PoissonNMF(n_components=n_components, random_state=98765, verbose=True)

# %%
tagger.set_components(online_coder_full.gamma_b[:, :K], online_coder_full.rho_b[:, :K])

# %%
Et = tagger.transform(X_test)
# Out:
# After ITERATION: 0	Objective: -1255688.17	Old objective: -inf	Improvement: nan
# After ITERATION: 1	Objective: -755262.20	Old objective: -1255688.17	Improvement: 0.39853
# After ITERATION: 2	Objective: -584625.24	Old objective: -755262.20	Improvement: 0.22593
# After ITERATION: 3	Objective: -508304.57	Old objective: -584625.24	Improvement: 0.13055
# After ITERATION: 4	Objective: -469691.26	Old objective: -508304.57	Improvement: 0.07596
# After ITERATION: 5	Objective: -448577.61	Old objective: -469691.26	Improvement: 0.04495
# After ITERATION: 6	Objective: -435737.63	Old objective: -448577.61	Improvement: 0.02862
# After ITERATION: 7	Objective: -427134.14	Old objective: -435737.63	Improvement: 0.01974
# After ITERATION: 8	Objective: -421046.89	Old objective: -427134.14	Improvement: 0.01425
# After ITERATION: 9	Objective: -416534.45	Old objective: -421046.89	Improvement: 0.01072
# After ITERATION: 10	Objective: -413066.50	Old objective: -416534.45	Improvement: 0.00833
# After ITERATION: 11	Objective: -410320.99	Old objective: -413066.50	Improvement: 0.00665
# After ITERATION: 12	Objective: -408090.54	Old objective: -410320.99	Improvement: 0.00544
# After ITERATION: 13	Objective: -406268.33	Old objective: -408090.54	Improvement: 0.00447
# After ITERATION: 14	Objective: -404753.63	Old objective: -406268.33	Improvement: 0.00373
# After ITERATION: 15	Objective: -403480.56	Old objective: -404753.63	Improvement: 0.00315
# After ITERATION: 16	Objective: -402405.17	Old objective: -403480.56	Improvement: 0.00267
# After ITERATION: 17	Objective: -401485.48	Old objective: -402405.17	Improvement: 0.00229
# After ITERATION: 18	Objective: -400697.23	Old objective: -401485.48	Improvement: 0.00196
# After ITERATION: 19	Objective: -400010.07	Old objective: -400697.23	Improvement: 0.00171
# After ITERATION: 20	Objective: -399410.01	Old objective: -400010.07	Improvement: 0.00150
# After ITERATION: 21	Objective: -398874.80	Old objective: -399410.01	Improvement: 0.00134
# After ITERATION: 22	Objective: -398405.81	Old objective: -398874.80	Improvement: 0.00118
# After ITERATION: 23	Objective: -397997.16	Old objective: -398405.81	Improvement: 0.00103
# After ITERATION: 24	Objective: -397622.40	Old objective: -397997.16	Improvement: 0.00094
# After ITERATION: 25	Objective: -397277.58	Old objective: -397622.40	Improvement: 0.00087
# After ITERATION: 26	Objective: -396970.95	Old objective: -397277.58	Improvement: 0.00077
# After ITERATION: 27	Objective: -396691.66	Old objective: -396970.95	Improvement: 0.00070
# After ITERATION: 28	Objective: -396439.16	Old objective: -396691.66	Improvement: 0.00064
# After ITERATION: 29	Objective: -396207.12	Old objective: -396439.16	Improvement: 0.00059
# After ITERATION: 30	Objective: -395995.87	Old objective: -396207.12	Improvement: 0.00053
# After ITERATION: 31	Objective: -395805.02	Old objective: -395995.87	Improvement: 0.00048

# %%
tags_predicted = Et.dot(online_coder_full.Eb[:, K:])
n_samples, n_tags = tags_predicted.shape

print tags_predicted.min(), tags_predicted.max()

div_factor = 3
tags_predicted = tags_predicted - div_factor * np.mean(tags_predicted, axis=0)
# Out:
# 1.67125215777e-05 2.66156080397

# %%
predictat = 20
tags_predicted_binary = construct_pred_mask(tags_predicted, predictat)
tags_true_binary = (y_test > 0)

# %%
prec, recall = per_tag_prec_recall(tags_predicted_binary, tags_true_binary)
print np.mean(prec), np.std(prec) / sqrt(n_tags)
print np.mean(recall), np.std(recall) / sqrt(n_tags)
# Out:
# 0.122749565216 0.0072130559867
# 0.140217804048 0.00753944408001

# %%
import cPickle as pickle

# %%
with open('online_NMF_K%d_N%d_S%d.cPickle' % (K, n_components, online_coder_full.batch_size), 'wb') as f:
    pickle.dump(online_coder_full, f)
